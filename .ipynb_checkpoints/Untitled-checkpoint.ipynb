# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from nose.tools import *

import skimage.io

# %%
im = skimage.io.imread("https://lh4.googleusercontent.com/O4xOxs7rftenKIzA9C5Ujarfrtn-z26IPrOZn9yLSMOfNBISUk4G8ESmUGqqIf3MNLLlQQgVWPHcHRKN4hJdKRTvQ_Hj3eQz5py1dE-r3eukcU8sAIHAPC6M4n-9SAct=w626")

skimage.io.imshow(im)
plt.show()

im.shape
# Out:
# (417, 626, 3)

# %%
np.mean(im[:, :, 0]) # R
# Out:
# 90.03931551244628

# %%
np.mean(im[:, :, 1])
# Out:
# 84.06009377801273

# %%
np.mean(im[:, :, 2])
# Out:
# 37.236755004941735
